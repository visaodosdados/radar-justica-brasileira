# %% [markdown]
# <a href="https://colab.research.google.com/github/visaodosdados/radar-justica-brasileira/blob/main/Radar_Justica_Brasileira_Extracao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
BASE_PATH = "/content/drive/MyDrive/Visão dos Dados/Projeto_01_Radar_Justica_Brasileira"

RAW_PATH = f"{BASE_PATH}/Dados_Brutos"
PROCESSED_PATH = f"{BASE_PATH}/Dados_Tratados"

# %%
# !pip install pandas requests openpyxl
